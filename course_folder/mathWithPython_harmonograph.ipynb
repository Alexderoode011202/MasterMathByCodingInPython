# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Introduction
# # VIDEO: Create a beautiful harmonograph!
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/mathWithPython_harmonograph.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# leave these parameters as-is
n = 1000000
t = np.logspace(np.log10(10),np.log10(500),n)

# try chaning these parameters
A = [  1, 2, 1.5, 3 ]
d = [ .004, .001, .0023, .0015 ]
f = [   10, 1, 0, 2.5 ]

# generate XY value pairs
x = A[0]*np.sin(t*f[0])*np.exp(-d[0]*t) + A[1]*np.sin(t*f[1])*np.exp(-d[1]*t)
y = A[2]*np.sin(t*f[2])*np.exp(-d[2]*t) + A[3]*np.sin(t*f[3])*np.exp(-d[3]*t)

# plot them!
plt.plot(x,y,'k',linewidth=.1)
plt.axis('off')
plt.show()

# %%
# what are the elementary components of the plots above? Let's have a look!
plt.plot(np.sin(t*f[0])*np.exp(-d[0]*2*t),linewidth=.5)
plt.show()
