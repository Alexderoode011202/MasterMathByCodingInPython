# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Calculus
# # VIDEO: Indefinite and definite integrals
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/calculus/mathWithPython_calc_integrals.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries

import sympy as sym
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks
from IPython.display import display,Math

# %%
x = sym.symbols('x')

# a simple function
f = x

# indefinite integration
sym.integrate(f) # notice no constant term
# Out:
# x**2/2

# %%
# definite integation (within bounds)
sym.integrate(f,(x,0,1))
# Out:
# 1/2

# %%
# plotting...

lowbnd = 2 # add later

f = x**3 / (x-lowbnd)
intf = sym.integrate(f)
p = sym.plotting.plot(f,show=False)
p.extend( sym.plotting.plot(intf,(x,2.1,10),show=False,line_color='r') )

p.xlim = [-10,10]
p.ylim = [-200,200]

p[0].label = '$f(x)$'
p[1].label = '$\\int f(x)dx$'
p.legend = True
p.show()

display(Math('f(x) = %s' %sym.latex(f)))
display(Math('\\int f(x) dx = %s' %sym.latex(intf)))
# Out:
# $\displaystyle f(x) = \frac{x^{3}}{x - 2}$
# $\displaystyle \int f(x) dx = \frac{x^{3}}{3} + x^{2} + 4 x + 8 \log{\left(x - 2 \right)}$

# %% [markdown]
# # Exercise

# %%
# show that the antiderivative (indefinite integral) of the derivative is the original function

f = 2*x**3 + sym.sin(x)

df = sym.diff(f)
idf = sym.integrate(df)

display(Math('f(x)=%s' %sym.latex(f)))
display(Math('f\'=%s' %sym.latex(df)))
display(Math('\\int (f\')dx=%s' %sym.latex(idf)))
# Out:
# $\displaystyle f(x)=2 x^{3} + \sin{\left(x \right)}$
# $\displaystyle f'=6 x^{2} + \cos{\left(x \right)}$
# $\displaystyle \int (f')dx=2 x^{3} + \sin{\left(x \right)}$
