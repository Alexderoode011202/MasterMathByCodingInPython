# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Graphing
# # VIDEO: Graphing rational functions
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MasterMathByCodingInPython/blob/main/graphing/mathWithPython_graph_rational.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries
import sympy as sym
import numpy as np
from IPython.display import display, Math
import matplotlib.pyplot as plt

# %%
x = sym.Symbol("x")
form = sym.sympify(2 + sym.sqrt(abs(x)))
display(form)
# Out:
# sqrt(Abs(x)) + 2

# %%
x = range(-3,4)
y = np.zeros(len(x))

for i in range(0,len(x)):
  y[i] = 2 - x[i]**2

plt.plot(x,y,'s-')
plt.xlabel('x'), plt.ylabel('y')
plt.show()

# %%
# what if you want more spacing?

x = np.linspace(-3,4,14)
y = 2 + np.sqrt(abs(x))

plt.plot(x,y,'s-')
plt.show()

# %%
x = np.linspace(-10,10, 1000)
y = x**2-5*x+3
z = -5*x + 3
plt.plot(x,y, label="$x^2-5 \\times x+3$")
plt.plot(x,z, label="$-5\\times x+3$")
plt.legend()
plt.grid()

# %% [markdown]
# # Exercise

# %%
e = range(-1,4)
x = np.linspace(-4,4,300)

for i in e:
  y = x**i
  plt.plot(x,y,label='$y=x{%s}$'%i,linewidth=4)

plt.legend()
plt.ylim([-20,20])
plt.xlim([x[0],x[-1]])
plt.xlabel('x')
plt.ylabel('y')
plt.show()
