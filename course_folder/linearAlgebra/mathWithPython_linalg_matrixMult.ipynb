#    2.63128198e+00  2.99446167e+00 -2.72918022e+00 -1.59912387e+00
#    8.79612326e-01 -3.57724421e+00  5.23709788e-01  9.55639636e-01
#   -3.56936268e+00 -2.13475935e-01]
#  [ 2.59561902e+00 -2.82048373e+00 -9.94847835e-01  9.84223705e-01
#    3.22411174e+00  4.97264273e+00 -3.72794198e+00  1.85262613e+00
#   -1.65819543e-01 -2.68724222e+00 -2.11068395e+00  1.73182962e+00
#   -8.47289746e+00  7.26776640e-01]
#  [ 2.78383774e+00 -3.67496221e+00  4.76264687e-01  2.93119230e+00
#    4.46096498e-01  2.44281597e+00 -4.26876575e-01  9.92774057e-01
#   -2.44579532e+00 -6.79610148e+00  1.54076851e+00 -4.75969892e-01
#   -1.26711595e-01 -3.16806001e+00]
#  [ 3.06958026e-01  2.32743471e-01 -3.38961278e+00 -2.86689563e+00
#   -2.13626970e+00  1.36882521e+00  6.66397934e+00 -1.02751130e+00
#   -4.16412693e-01  4.38820382e+00  9.05403597e-01 -1.76756552e+00
#    2.09375707e+00  2.12346671e+00]]
# [[ -2.85297285  -4.10897749   1.60788723  -0.95335231  -1.94994706
#    -0.9991125   -4.40374458   1.25992324  -7.28555256   7.50952651]
#  [ -6.56311764  -0.56712185  -1.42571939   4.08891221   7.28542392
#     0.78597888   2.56912682   0.08046001   0.36295146  -1.4696195 ]
#  [  3.97557555   2.5590621    1.60776584   5.2754028    0.24022033
#    -2.38138756  -0.11624672   1.78872434  -1.22666616   2.7161582 ]
#  [  1.72872564  -3.3090185   -2.01766387  -1.09333053  -2.13098083
#    -2.32136004   1.10244026   3.67856     -1.91094633   2.54918146]
#  [ -3.63785851  -5.15498165   1.22909589  -3.72651434  -0.41092914
#     1.72311149  -3.28443485   6.96915395  -5.62059891   7.52800552]
#  [  2.46909799   0.72229466   0.12959284   5.24693415   2.54294949
#    -3.61197246  -4.07616753  -0.46744931  -2.55438837   4.91738189]
#  [ -1.02200069   0.56638243   6.81204223  -0.48671228  -2.50642146
#    -1.92491095  -0.03997023   6.64840887   2.14415484   6.28856448]
#  [  2.17713811  -4.33194507  -0.07300953  -0.96338049  -1.00975082
#    -4.70876338  -5.99120345  -2.08485317 -10.0274002    2.93321311]
#  [  6.09799201   3.7700676    4.22471284   2.33076702  -3.70697344
#    -2.06745524  -5.03165157  -3.15612644   0.2822013    2.41369718]
#  [ -3.73577912  -0.10816074  -2.35036876   1.98156153   0.04017329
#     0.80262926   3.13768462   4.37412389   1.53122384   4.33516571]]

# %% [markdown]
# # Exercise

# %%
def matrixMultiplication(A,B):

  # get matrix sizes
  szA = np.shape(A)
  szB = np.shape(B)

  # give error if sizes don't match
  if szA[1]!=szB[0]:
    raise ValueError('"Inner" dimensions don''t match!')

  # initialize
  C = np.zeros((szA[0],szB[1]))

  # compute!
  for i in range(szA[0]):
    for j in range(szB[1]):
      C[i,j] = np.dot(A[i,:],B[:,j])

  return C

# %%
A = np.random.randn(4,6)
B = np.random.randn(5,2)

C1 = matrixMultiplication(A,B)
C2 = A@B

print(C1-C2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 A = np.random.randn(4,6)
#       2 B = np.random.randn(5,2)
# ----> 4 C1 = matrixMultiplication(A,B)
#       5 C2 = A@B
#       7 print(C1-C2)
#
# Cell In[3], line 9, in matrixMultiplication(A, B)
#       7 # give error if sizes don't match
#       8 if szA[1]!=szB[0]:
# ----> 9   raise ValueError('"Inner" dimensions don''t match!')
#      11 # initialize
#      12 C = np.zeros((szA[0],szB[1]))
#
# ValueError: "Inner" dimensions dont match!
