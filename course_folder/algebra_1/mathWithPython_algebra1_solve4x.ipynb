# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 1
# # VIDEO: Solving for x
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MasterMathByCodingInPython/blob/main/algebra_1/mathWithPython_algebra1_solve4x.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# It's generally good practice to import all required modules at the top of the script!
import sympy as sym
import numpy as np
from IPython.display import display, Math
sym.init_printing()

# %%
x = sym.symbols('x')

# the expression we want to solve is 2x+4=9
expr = 2*x + 4 - 9
print(sym.latex(expr))
sym.solve(expr,x)

display(Math("%s = 0" % (expr)))

display(Math("2x - 5"))

display(Math("%s \\quad \\rightarrow \\quad x = %s"%(expr, sym.solve(expr)[0])))

own_expression = x**2 - 4

display(own_expression)

display(Math("%s = 0 \\text{ means that } x = %s"%(sym.latex(own_expression), sym.solve(own_expression))))
# Out:
# 2 x - 5
# $\displaystyle 2*x - 5 = 0$
# $\displaystyle 2x - 5$
# $\displaystyle 2*x - 5 \quad \rightarrow \quad x = 5/2$
#  2
# x  - 4
# $\displaystyle x^{2} - 4 = 0 \text{ means that } x = [-2, 2]$

# %%
# MY OWN STUFF!!!!

test = sym.sympify("3*x**2 + 5*x - 3")
display(test)
display(sym.solve(test))
# Out:
#    2
# 3⋅x  + 5⋅x - 3
# ⎡  5   √61    √61   5⎤
# ⎢- ─ + ───, - ─── - ─⎥
# ⎣  6    6      6    6⎦

# %%
# make it look a bit nicer

sol = sym.solve(expr,x)

display('The solution to %s is %g'%(expr,sol[0]))

# or
display(Math('\\text{The solution to }%s\\text{ is x=}%g' %(sym.latex(expr),sol[0])))
# Out:
# 'The solution to 2*x - 5 is 2.5'
# $\displaystyle \text{The solution to }2 x - 5\text{ is x=}2.5$

# %%
# can input the equation directly into the solve function
sym.solve(x**2 - 4,x)
# Out:
# [-2, 2]

# %%
# notice the solution is stored as a list, with one solution per element
sol = sym.solve(x**2 - 4,x)

print( type(sol) )
print( len(sol) )
# Out:
# <class 'list'>
# 2

# %%
# we can print them all out:
for i in range(0,len(sol)):
  print('Solution #' + str(i+1) + ' is ' + str(sol[i]))
# Out:
# Solution #1 is -2
# Solution #2 is 2

# %%
y = sym.symbols('y')

expr = x/4 - x*y + 5

print( "Solved for x: " + str(sym.solve(expr,x)[0]) )
print( "Solved for y: " + str(sym.solve(expr,y)) )
# Out:
# Solved for x: 20/(4*y - 1)
# Solved for y: [(x + 20)/(4*x)]

# %% [markdown]
# # Exercises

# %%
# 1)
# simplify and solve for q
q = sym.symbols('q')
eq = 3*q + 4/q + 3 - 5*q - 1/q - 1

display(Math(sym.latex(eq.simplify())))
display(Math('q='+sym.latex(sym.solve(eq,q))))
# Out:
# $\displaystyle - 2 q + 2 + \frac{3}{q}$
# $\displaystyle q=\left[ \frac{1}{2} - \frac{\sqrt{7}}{2}, \  \frac{1}{2} + \frac{\sqrt{7}}{2}\right]$

# %%
# 2)
eq = 2*q + 3*q**2 - 5/q - 4/q**3

display(Math(sym.latex(eq)))
display(Math(sym.latex(sym.simplify(eq))))
display(Math(sym.latex(sym.cancel(eq)))) # puts into p/q form with integer coefficients
# Out:
# $\displaystyle 3 q^{2} + 2 q - \frac{5}{q} - \frac{4}{q^{3}}$
# $\displaystyle 3 q^{2} + 2 q - \frac{5}{q} - \frac{4}{q^{3}}$
# $\displaystyle \frac{3 q^{5} + 2 q^{4} - 5 q^{2} - 4}{q^{3}}$

# %%
# 3)
# simplify this expression. confirm on your own using paper-and-pencil
expr = (sym.sqrt(3) + sym.sqrt(15)*q) / (sym.sqrt(2) + sym.sqrt(10)*q)
display(Math(sym.latex(expr)))
display(Math(sym.latex(sym.simplify(expr))))
# Out:
# $\displaystyle \frac{\sqrt{15} q + \sqrt{3}}{\sqrt{10} q + \sqrt{2}}$
# $\displaystyle \frac{\sqrt{6}}{2}$

# %%
sym.simplify( expr.subs(q,10) )
# Out:
# √6
# ──
# 2

# %%
expr.subs(q,10).evalf()
# Out:
# 1.22474487139159

# %%
a,b,c = sym.symbols("a,b,c")
express1 = sym.sympify("3*a*c + sqrt(c)-abs(a)")
display(express1)

express2 = express1.subs({a: -3})
display(express2)


display(Math("f(c) = %s \\quad \\text{with } c = 5 \\rightarrow \\quad c= %s"%(sym.latex(express2), sym.latex(express2.subs(c, 5)))))
# Out:
# 3⋅a⋅c + √c - │a│
# √c - 9⋅c - 3
# $\displaystyle f(c) = \sqrt{c} - 9 c - 3 \quad \text{with } c = 5 \rightarrow \quad c= -48 + \sqrt{5}$
