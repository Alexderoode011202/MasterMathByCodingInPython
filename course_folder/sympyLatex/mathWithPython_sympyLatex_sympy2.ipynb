# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Introduction to Sympy and Latex
# # VIDEO: Intro to sympy, part 2
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/sympyLatex/mathWithPython_sympyLatex_sympy2.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries
import sympy as sym
from IPython.display import display,Math

# %%
# using Greek characters as variable names

mu,alpha,sigma = sym.symbols('mu,alpha,sigma')

expr = sym.exp( (mu-alpha)**2/ (2*sigma**2) )

display(expr)
# Out:
# exp((-alpha + mu)**2/(2*sigma**2))

# %%
# can also use longer and more informative variable names
hello = sym.symbols('hello')

hello/3

x = sym.Symbol("x")
mu = sym.Symbol("mu")
mu
# Out:
# mu

# %%
# substituting numbers for variables

# don't forget to define variables before using them!
display(x+4)

(x+4).subs(x,3)
# Out:
# x + 4
# 7

# %%
# substituting multiple variables

x,y = sym.symbols('x,y') # can create multiple variables in one line
expr = x+y+5

# substituting one variable
print( expr.subs(x,5) )

# substituting multiple variables
print( expr.subs({x:5,y:4}) )
# Out:
# y + 10
# 14

# %%
# using sympy to print latex code
expr = 3/x

print( sym.latex(expr) )

# notice:
print( sym.latex(3/4) )
print( sym.latex('3/4') )
# but
print( sym.latex(sym.sympify('3/4')) )
# Out:
# \frac{3}{x}
# 0.75
# \mathtt{\text{3/4}}
# \frac{3}{4}

# %%
x, y = sym.symbols("x, y")
my_expression = 5*x**2 + 4*y + 3

display(Math(sym.latex(my_expression)))

display(Math(sym.latex(my_expression.subs(x, 1))))
# Out:
# $\displaystyle 5 x^{2} + 4 y + 3$
# $\displaystyle 4 y + 8$

# %% [markdown]
# $5 x^{2} + 4 y + 3$

# %% [markdown]
# # Exercise

# %%
for i in range(-2,3):
  ans = (x+4).subs(x,i**2)
  display(Math('\\text{With }x=%g:\; x^2+4 \\quad \\Rightarrow \\quad %g^2+4 =%g' %(i,i,ans)))
# Out:
# $\displaystyle \text{With }x=-2:\; x^2+4 \quad \Rightarrow \quad -2^2+4 =8$
# $\displaystyle \text{With }x=-1:\; x^2+4 \quad \Rightarrow \quad -1^2+4 =5$
# $\displaystyle \text{With }x=0:\; x^2+4 \quad \Rightarrow \quad 0^2+4 =4$
# $\displaystyle \text{With }x=1:\; x^2+4 \quad \Rightarrow \quad 1^2+4 =5$
# $\displaystyle \text{With }x=2:\; x^2+4 \quad \Rightarrow \quad 2^2+4 =8$

# %%
x = sym.Symbol("x")
my_expression = x**2+4

display(my_expression)
# display(Math(sym.latex(my_expression.subs(x,3))))

for num in range(-2,3):
    display(Math("\\text{with } x = %a, \\quad x^2+4 \\quad \\rightarrow \\quad %a^2+4=%a "%(num, num, my_expression.subs(x,num))))
# Out:
# x**2 + 4
# $\displaystyle \text{with } x = -2, \quad x^2+4 \quad \rightarrow \quad -2^2+4=8 $
# $\displaystyle \text{with } x = -1, \quad x^2+4 \quad \rightarrow \quad -1^2+4=5 $
# $\displaystyle \text{with } x = 0, \quad x^2+4 \quad \rightarrow \quad 0^2+4=4 $
# $\displaystyle \text{with } x = 1, \quad x^2+4 \quad \rightarrow \quad 1^2+4=5 $
# $\displaystyle \text{with } x = 2, \quad x^2+4 \quad \rightarrow \quad 2^2+4=8 $

# %%
a,b,c = sym.symbols("a,b,c")

expr = sym.sympify("a**b * b**c")
display(expr)
print(sym.latex(expr))
display(Math(str(sym.latex(expr))))
# Out:
# a**b*b**c
# a^{b} b^{c}
# $\displaystyle a^{b} b^{c}$
