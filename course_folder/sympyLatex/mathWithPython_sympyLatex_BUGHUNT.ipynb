# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Introduction to Sympy and Latex
# # VIDEO: Sympy/latex bug hunt!
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/sympyLatex/mathWithPython_sympyLatex_BUGHUNT.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import sympy as sym
from IPython.display import display, Math

# %%
mu,alpha = sym.symbols('mu,alpha')

expr = 2*sym.exp(mu**2/alpha)

display(Math( expr ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 mu,alpha = sym.symbols('mu,alpha')
#       3 expr = sym.exp(2*(mu**2/alpha))
# ----> 5 display(Math( expr ))
#
# File ~/anaconda3/envs/new/lib/python3.11/site-packages/IPython/core/display.py:328, in DisplayObject.__init__(self, data, url, filename, metadata)
#     325     self.metadata = {}
#     327 self.reload()
# --> 328 self._check_data()
#
# File ~/anaconda3/envs/new/lib/python3.11/site-packages/IPython/core/display.py:407, in TextDisplayObject._check_data(self)
#     405 def _check_data(self):
#     406     if self.data is not None and not isinstance(self.data, str):
# --> 407         raise TypeError("%s expects text, not %r" % (self.__class__.__name__, self.data))
#
# TypeError: Math expects text, not exp(2*mu**2/alpha)

# %%
mu,alpha = sym.symbols('mu,alpha')

expr = 2*sym.exp(mu**2/alpha)

display(expr)
# Out:
# 2*exp(mu**2/alpha)

# %%
Math('1234 + \\frac{3x}{\\sin(2\\pi t+\\theta)}')
# Out:
# $\displaystyle 1234 + \frac{3x}{\sin(2\pi t+\theta)}$

# %%
a = '3'
b = '4'

# answer should be 7
print(sym.sympify(a+b))
# Out:
# 34

# %%
x = sym.Symbol("x")
sym.Eq( 4*x, 2 )
# Out:
# Eq(4*x, 2)

# %%
# part 1 of 2

#q = x^2
r = x**2

#display(q)
display(r)
# Out:
# x**2

# %%
# part 2 of 2

q,r = sym.symbols('q,r')

q = sym.sympify('x^2')
r = sym.sympify('x**2')

display(q)
display(r)

sym.Eq(q,r)
# Out:
# x**2
# x**2
# True

# %%
x = sym.symbols('x')

equation = (4*x**2 - 5*x + 10)**(1/2)
display(equation)
sym.subs(equation,x,3)
# Out:
# (4*x**2 - 5*x + 10)**0.5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 5
#       3 equation = (4*x**2 - 5*x + 10)**(1/2)
#       4 display(equation)
# ----> 5 sym.subs(equation,x,3)
#
# AttributeError: module 'sympy' has no attribute 'subs'

# %%
x,y = sym.symbols('x,y')

equation = 1/4*x*y**2 - x*(5*x + 10*y**2)**(3)
display(sym.simplify(sym.simplify(equation)))
display(equation)
# Out:
# x*(0.25*y**2 - 125*(x + 2*y**2)**3)
# 0.25*x*y**2 - x*(5*x + 10*y**2)**3
