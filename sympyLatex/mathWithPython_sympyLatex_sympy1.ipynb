# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Introduction to Sympy and Latex
# # VIDEO: Intro to sympy, part 1
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/sympyLatex/mathWithPython_sympyLatex_sympy1.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# %pip install sympy
# Out:
# Requirement already satisfied: sympy in /home/alex/anaconda3/envs/new/lib/python3.11/site-packages (1.12)
# Requirement already satisfied: mpmath>=0.19 in /home/alex/anaconda3/envs/new/lib/python3.11/site-packages (from sympy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the sympy package
import sympy as sym

# import additional functions for nice printing
from IPython.display import display, Math

# %%
# create symbolic variables
x,y,z = sym.symbols('x,y,z')

x
# Out:
# x

# %%
# x doesn't have a value; it's just a symbol
x + 4
# Out:
# x + 4

# %%
# more fun...
display( x**y )
display( y/z )
# Out:
# x**y
# y/z

# %%
# let's compare with numpy
import numpy as np

display(sym.sqrt(2)) # square root in symbolic math
display(np.sqrt(2)) # square root in numeric/precision math
# Out:
# sqrt(2)
# 1.4142135623730951

# %% [markdown]
# # Exercises

# %%
# 1)
display(y*x**2)

# 2)
display( sym.sqrt(4)*x )

# 3)
display( sym.sqrt(x)*sym.sqrt(x) )
# Out:
# x**2*y
# 2*x
# x

# %%
from IPython.display import display, Math
x, y, z = sym.symbols(names= "x, y, z")
display(Math("4x+5y-8z=17"))
display(Math("\\sin(2\\pi ft + \\theta)"))
display(Math("e=mc^2"))
display(Math("\\frac{4+5x^2}{(1+x)(1-x)}"))
display(Math("A_{3 \\times 3}"))
# Out:
# $\displaystyle 4x+5y-8z=17$
# $\displaystyle \sin(2\pi ft + \theta)$
# $\displaystyle e=mc^2$
# $\displaystyle \frac{4+5x^2}{(1+x)(1-x)}$
# $\displaystyle A_{3 \times 3}$

# %% [markdown]
# Eintstein's most famous formula is: $e=mc^2$. <br>
# An example of a polynomial is: $ 5x^2+3x+1$. <br>
# A 3x3 indentity matrix gets expressed as: $ I_{3 \times 3} $. <br>
# The inverse of matrix $A$ is $A_{-1}$
